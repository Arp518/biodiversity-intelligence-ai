# %%
import sys
import pandas as pd
import numpy as np
import matplotlib

print("Python:", sys.version)
print("Python path:", sys.executable)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Matplotlib:", matplotlib.__version__)
# Out:
# Python: 3.11.8 (tags/v3.11.8:db85d51, Feb  6 2024, 22:03:32) [MSC v.1937 64 bit (AMD64)]
# Python path: c:\Users\shubham chavan\OneDrive\Documents\Desktop\biodiversity-intelligence-ai\.venv\Scripts\python.exe
# Pandas: 3.0.5
# NumPy: 2.4.6
# Matplotlib: 3.11.2

# %%
import pandas as pd

golden_cases = pd.read_csv("../data/evaluation/golden_cases.csv")

golden_cases.head()
# Out:
#   case_id                                           question known_soc  \
# 0    GC01  A farm has low soil organic carbon, low rainfa...      0.3%
# 1    GC02  My land already has good soil carbon, decent r...      1.8%
# 2    GC03  Biodiversity is declining on my land. Soil org...      0.4%
# 3    GC04  We get decent rainfall but our soil carbon is ...       low
# 4    GC05  What can I do to improve biodiversity on this ...   unknown
#
#   known_rainfall     known_land_use  known_biodiversity  \
# 0            low  monoculture wheat   low species count
# 1       adequate       agroforestry  high species count
# 2        unknown            unknown           declining
# 3       adequate  monoculture wheat             unknown
# 4        unknown  monoculture wheat             unknown
#
#                                    missing_variables  \
# 0                                               none
# 1                                               none
# 2                                 rainfall, land use
# 3                             biodiversity indicator
# 4  soil organic carbon, rainfall, biodiversity in...
#
#                                   required_knowledge  \
# 0  SOC <-> soil/ecosystem condition; SOC <-> biod...
# 1  Maintenance-level agroforestry/high-biodiversi...
# 2  SOC <-> biodiversity decline indicators; what ...
# 3  SOC <-> monoculture interaction effects; how a...
# 4  General monoculture <-> biodiversity evidence ...
#
#                                    expected_behavior  \
# 0  Notice SOC + rainfall + land use + biodiversit...
# 1  Recognize this is a positive baseline; suggest...
# 2  Ask a targeted clarifying question for rainfal...
# 3  Reason about SOC + land use with rainfall as a...
# 4  Ask for the missing core variables (at minimum...
#
#                                   forbidden_behavior
# 0  Recommend generic 'plant more trees' without a...
# 1  Recommend a drastic intervention when conditio...
# 2  Fabricate rainfall or land use to produce an a...
# 3  Assume biodiversity is low without evidence or...
# 4  Provide a fully specific, quantified recommend...

# %%
golden_cases.shape
# Out:
# (8, 10)

# %%
golden_cases.columns.tolist()
# Out:
# ['case_id',
#  'question',
#  'known_soc',
#  'known_rainfall',
#  'known_land_use',
#  'known_biodiversity',
#  'missing_variables',
#  'required_knowledge',
#  'expected_behavior',
#  'forbidden_behavior']

# %%
golden_cases["case_id"].tolist()
# Out:
# ['GC01', 'GC02', 'GC03', 'GC04', 'GC05', 'GC06', 'GC07', 'GC08']

# %%
golden_cases.isnull().sum()
# Out:
# case_id               0
# question              0
# known_soc             0
# known_rainfall        0
# known_land_use        0
# known_biodiversity    0
# missing_variables     0
# required_knowledge    0
# expected_behavior     0
# forbidden_behavior    0
# dtype: int64
